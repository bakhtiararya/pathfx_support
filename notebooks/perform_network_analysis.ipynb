# %%
import networkx as nx
import random
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
from matplotlib import pyplot
import seaborn as sns
sns.set()
sns.set_context("talk")
import numpy as np
import pandas as pd
import pickle 
import os
import sys
import shutil
# Run this to suppress all DeprecationWarnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
sns.set_theme()
np.random.seed(0)

# %%
"""
Helper Functions
"""

# function checks if directory exists, if not it constructs it
def check_directory_exists(dir_name):
    if not os.path.exists(dir_name):
        os.makedirs(dir_name)

# function saves DataFrame, list, or set as a textfile in a specific folder
def save_to_text_file(output_folder_dest, input_data, text_file_name):
    text_file_ouput = output_folder_dest + text_file_name + ".txt"
    drug_output_info_file = open(text_file_ouput, 'w+')
    if isinstance(input_data, pd.DataFrame):
        drug_output_info_file.write(input_data.to_string())
    else:
        drug_output_info_file.write(str(input_data))
    drug_output_info_file.close() 
    print("Constructed and saved", text_file_ouput)

# Read in Pickle File
def read_pickle_file(file_path):
    if not os.path.exists(file_path):
        sys.exit("Can't locate input file %s" % file_path)
    return pd.read_pickle(file_path)
    
# Save data into a pickel file
def save_to_pickle_file(output_folder_dest, dict_data, dict_file_name):
    output_dict_filename = output_folder_dest + dict_file_name + '.pkl'
    with open(output_dict_filename, 'wb') as handle:
        pickle.dump(dict_data, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print("Constructed and saved", output_dict_filename)

# Read in a CSV file
def read_csv_file(file_path, input_sep=',', input_delimiter=None, input_index_col=None, input_dtype=None, input_delim_whitespace=False, input_low_memory=True):
    if not os.path.exists(file_path):
        sys.exit("Can't locate input file %s" % file_path)
    return pd.read_csv(filepath_or_buffer=file_path, sep=input_sep, delimiter=None, index_col=input_index_col, dtype=input_dtype, delim_whitespace=input_delim_whitespace, low_memory=input_low_memory)

# funcion saves DataFrame or list to as a textfile
def save_to_csv_file(output_folder_dest, df, csv_file_name, save_with_indexing=False):
    output_filename = output_folder_dest + csv_file_name + ".csv"
    df.to_csv(output_filename, index=save_with_indexing)
    print("Constructed and saved", output_filename)
    
def read_csv_file(file_path, input_sep=',', input_delimiter=None, input_index_col=None, input_dtype=None, input_delim_whitespace=False, input_low_memory=True):
    return pd.read_csv(filepath_or_buffer=file_path, sep=input_sep, delimiter=None, index_col=input_index_col, dtype=input_dtype, delim_whitespace=input_delim_whitespace, low_memory=input_low_memory)

def save_to_gpickle_file(output_folder_dest, data, file_name):
    output_filename = output_folder_dest + file_name + ".gpickle"
    nx.write_gpickle(data, output_filename)
    print("Constructed and saved", output_filename)
    
def read_networkx_gpickle_file(file_path):
    if not os.path.exists(input_file_name):
        sys.exit("Can't locate input file %s" % file_path)
    return nx.read_gpickle(file_path)

# %%
filter_type_dict = {"NOT_FILTERED_":[False, False, False, False], 
                    "FLTERED_FOR_SAME_EDGES_":[True, True, False, False], 
                    "FLTERED_FOR_SAME_NODES_":[True, False, True, False], 
                    "FLTERED_FOR_CLOSE_NODES_":[True, False, False, True]}

output_folder_lst = ['output_pathfx_network_analysis', 'output_string_network_analysis', 'output_comparison_network_analysis']

# %%
for filter_type in filter_type_dict.keys():
    
    print()
    print("Nework Analysis for Filter Type:", filter_type)
    print("================================================================================================ \n \n")
    
    filter_data, filter_for_same_edges, filter_for_same_nodes, filter_for_close_nodes = filter_type_dict[filter_type]
    
    print("Running clean_pathfx_score_table.ipynb ... \n")
    # %run ./clean_pathfx_score_table.ipynb
    print("Finished Running clean_pathfx_score_table.ipynb \n")

    print("Running clean_string_score_table.ipynb ... \n")
    # %run ./clean_string_score_table.ipynb
    print("Finished Running clean_string_score_table.ipynb \n")

    if(filter_data):
        print("Running filter_string_and_pathfx_score_tables.ipynb ... \n")
        # %run ./filter_string_and_pathfx_score_tables.ipynb
        print("Finished Running filter_string_and_pathfx_score_tables.ipynb \n")

    print("Running pathfx_network_analysis.ipynb ... \n")
    # %run ./pathfx_network_analysis.ipynb
    print("Finished Running pathfx_network_analysis.ipynb \n")

    print("Running string_network_analysis.ipynb ... \n")
    # %run ./string_network_analysis.ipynb
    print("Finished Running string_network_analysis.ipynb \n")

    print("Running comparison_network_analysis.ipynb ... \n")
    # %run ./comparison_network_analysis.ipynb
    print("Finished Running comparison_network_analysis.ipynb \n")

    print("Finished Running all iPython Notebooks \n")
    
    print("Saving Output Folders...")
    
    for output_folder in output_folder_lst:

        custom_folder_name = "outputs/" + filter_type + output_folder
    
        if os.path.exists(custom_folder_name):
    
            try:
                shutil.rmtree(custom_folder_name)
            except OSError as e:
                print("Error: %s : %s" % (custom_folder_name, e.strerror))

        os.rename("outputs/" + output_folder, custom_folder_name)
        
        print("Folder " + output_folder + " renamed to " + custom_folder_name + " successfully")
    
    print()
    print("================================================================================================ \n \n")
# Out:
# Nework Analysis for Filter Type: NOT_FILTERED_
# ================================================================================================
#
#
# Running clean_pathfx_score_table.ipynb ...
# 'pre_pathfx_score_df'
#            source          target    weight
# 0       rs1042713   isoproterenol  0.233675
# 1       rs1042713  Ace Inhibitors  0.285181
# 2       rs1042713     Angiotensin  0.285181
# 3       rs1042713           Plain  0.285181
# 4       rs1042713     risperidone  0.285181
# ...           ...             ...       ...
# 139082       VCAN            SELP  0.279930
# 139083       NFIC            NFIB  0.279930
# 139084       NFIB            NFIX  0.279930
# 139085       SELK            SELK  0.416595
# 139086       NFIX            NFIX  0.279930
#
# [139087 rows x 3 columns]
# Nonself Records:
# 'pre_pathfx_score_df'
#            source          target    weight
# 0       rs1042713   isoproterenol  0.233675
# 1       rs1042713  Ace Inhibitors  0.285181
# 2       rs1042713     Angiotensin  0.285181
# 3       rs1042713           Plain  0.285181
# 4       rs1042713     risperidone  0.285181
# ...           ...             ...       ...
# 139075     SFTPA2          SFTPA1  0.359348
# 139080       SELL            VCAN  0.279930
# 139082       VCAN            SELP  0.279930
# 139083       NFIC            NFIB  0.279930
# 139084       NFIB            NFIX  0.279930
#
# [136531 rows x 3 columns]
# Outputting Number of Distinct Proteins
# ------------------------------------------------
# Number of Unique sources: 17602
# Number of Unique targets: 18089
# Number of Unique sources and targets: 23970
# 'mirror_copy_pre_pathfx_score_df'
#                 source     target    weight
# 0        isoproterenol  rs1042713  0.233675
# 1       Ace Inhibitors  rs1042713  0.285181
# 2          Angiotensin  rs1042713  0.285181
# 3                Plain  rs1042713  0.285181
# 4          risperidone  rs1042713  0.285181
# ...                ...        ...       ...
# 139075          SFTPA1     SFTPA2  0.359348
# 139080            VCAN       SELL  0.279930
# 139082            SELP       VCAN  0.279930
# 139083            NFIB       NFIC  0.279930
# 139084            NFIX       NFIB  0.279930
#
# [136531 rows x 3 columns]
# 'pathfx_score_df'
#            source          target    weight
# 0       rs1042713   isoproterenol  0.233675
# 1       rs1042713  Ace Inhibitors  0.285181
# 2       rs1042713     Angiotensin  0.285181
# 3       rs1042713           Plain  0.285181
# 4       rs1042713     risperidone  0.285181
# ...           ...             ...       ...
# 139075     SFTPA1          SFTPA2  0.359348
# 139080       VCAN            SELL  0.279930
# 139082       SELP            VCAN  0.279930
# 139083       NFIB            NFIC  0.279930
# 139084       NFIX            NFIB  0.279930
#
# [273062 rows x 3 columns]
# Outputting Number of Distinct Proteins
# ------------------------------------------------
# Number of Unique sources: 23970
# Number of Unique targets: 23970
# Number of Unique sources and targets: 23970
#
# Constructed and saved outputs/output_clean_pathfx_score_table/pathfx_score_table.csv
# Constructed and saved inputs/input_pathfx_network_analysis/pathfx_score_table.csv
# Constructed and saved inputs/input_filter_string_and_pathfx_score_tables/pathfx_score_table.csv
# Finished Running clean_pathfx_score_table.ipynb
#
# Running clean_string_score_table.ipynb ...
# 'string_pre_score_df'
#                   Protein 1 ID          Protein 2 ID  experiments  database  \
# 0         9606.ENSP00000000233  9606.ENSP00000272298            0         0
# 1         9606.ENSP00000000233  9606.ENSP00000253401            0         0
# 2         9606.ENSP00000000233  9606.ENSP00000401445            0         0
# 3         9606.ENSP00000000233  9606.ENSP00000418915            0         0
# 4         9606.ENSP00000000233  9606.ENSP00000327801            0         0
# ...                        ...                   ...          ...       ...
# 11759449  9606.ENSP00000485678  9606.ENSP00000310488            0         0
# 11759450  9606.ENSP00000485678  9606.ENSP00000342448            0         0
# 11759451  9606.ENSP00000485678  9606.ENSP00000350222            0         0
# 11759452  9606.ENSP00000485678  9606.ENSP00000367590            0       900
# 11759453  9606.ENSP00000485678  9606.ENSP00000349930            0         0
#
#           textmining  Physical Combined Score
# 0                  0                       41
# 1                  0                       41
# 2                  0                       41
# 3                542                      542
# 4                  0                       41
# ...              ...                      ...
# 11759449           0                       41
# 11759450           0                       41
# 11759451           0                       41
# 11759452           0                      900
# 11759453           0                       41
#
# [11759454 rows x 6 columns]
# 'string_info_df'
#                  Protein ID          Protein  protein_size  \
# 0      9606.ENSP00000000233             ARF5           180
# 1      9606.ENSP00000000412             M6PR           277
# 2      9606.ENSP00000001008            FKBP4           459
# 3      9606.ENSP00000001146          CYP26B1           512
# 4      9606.ENSP00000002125          NDUFAF7           441
# ...                     ...              ...           ...
# 19561  9606.ENSP00000485671  ENSG00000280273           120
# 19562  9606.ENSP00000485672  ENSG00000279458            86
# 19563  9606.ENSP00000485673  ENSG00000279988           243
# 19564  9606.ENSP00000485675  ENSG00000280116            84
# 19565  9606.ENSP00000485678            OR6Q1           317
#
#                                               annotation
# 0      ADP-ribosylation factor 5; GTP-binding protein...
# 1      Cation-dependent mannose-6-phosphate receptor;...
# 2      Peptidyl-prolyl cis-trans isomerase FKBP4; Imm...
# 3      Cytochrome P450 26B1; Involved in the metaboli...
# 4      Protein arginine methyltransferase NDUFAF7, mi...
# ...                                                  ...
# 19561                                        HCG1991042
# 19562                           annotation not available
# 19563                           annotation not available
# 19564                           annotation not available
# 19565  Olfactory receptor 6Q1; Odorant receptor; Olfa...
#
# [19566 rows x 4 columns]
# 'string_score_df'
#          Protein 1          Protein 1 ID        Protein 2  \
# 0             ARF5  9606.ENSP00000000233            CALM2
# 1            FKBP4  9606.ENSP00000001008            CALM2
# 2          CYP51A1  9606.ENSP00000003100            CALM2
# 3             PDK4  9606.ENSP00000005178            CALM2
# 4             RALA  9606.ENSP00000005257            CALM2
# ...            ...                   ...              ...
# 11759449    DUX4L7  9606.ENSP00000451411  ENSG00000274175
# 11759450      DUX4  9606.ENSP00000458065  ENSG00000274175
# 11759451    DUX4L8  9606.ENSP00000485452  ENSG00000274175
# 11759452    DYNLL2  9606.ENSP00000477310         C17orf47
# 11759453    FAM65B  9606.ENSP00000482957         C6orf229
#
#                   Protein 2 ID  experiments  database  textmining  \
# 0         9606.ENSP00000272298            0         0           0
# 1         9606.ENSP00000272298            0         0           0
# 2         9606.ENSP00000272298            0         0           0
# 3         9606.ENSP00000272298            0         0         104
# 4         9606.ENSP00000272298          313         0           0
# ...                        ...          ...       ...         ...
# 11759449  9606.ENSP00000479378            0         0         560
# 11759450  9606.ENSP00000479378            0         0         556
# 11759451  9606.ENSP00000479378            0         0         559
# 11759452  9606.ENSP00000354874          212         0           0
# 11759453  9606.ENSP00000454913            0         0           0
#
#           Physical Combined Score
# 0                              41
# 1                              41
# 2                              41
# 3                             104
# 4                             313
# ...                           ...
# 11759449                      560
# 11759450                      556
# 11759451                      559
# 11759452                      212
# 11759453                       41
#
# [11759454 rows x 8 columns]
# 'self_interacting_protein'
#                Protein 1          Protein 1 ID        Protein 2  \
# 2674693  ENSG00000243667  9606.ENSP00000295121  ENSG00000243667
# 7375638  ENSG00000216937  9606.ENSP00000364165  ENSG00000216937
# 7409667  ENSG00000216937  9606.ENSP00000355078  ENSG00000216937
# 8264678  ENSG00000243667  9606.ENSP00000477980  ENSG00000243667
#
#                  Protein 2 ID  experiments  database  textmining  \
# 2674693  9606.ENSP00000477980          800         0           0
# 7375638  9606.ENSP00000355078            0         0           0
# 7409667  9606.ENSP00000364165            0         0           0
# 8264678  9606.ENSP00000295121          800         0           0
#
#          Physical Combined Score
# 2674693                      800
# 7375638                       41
# 7409667                       41
# 8264678                      800
# 'non_self_interacting_protein'
#          Protein 1          Protein 1 ID        Protein 2  \
# 0             ARF5  9606.ENSP00000000233            CALM2
# 1            FKBP4  9606.ENSP00000001008            CALM2
# 2          CYP51A1  9606.ENSP00000003100            CALM2
# 3             PDK4  9606.ENSP00000005178            CALM2
# 4             RALA  9606.ENSP00000005257            CALM2
# ...            ...                   ...              ...
# 11759449    DUX4L7  9606.ENSP00000451411  ENSG00000274175
# 11759450      DUX4  9606.ENSP00000458065  ENSG00000274175
# 11759451    DUX4L8  9606.ENSP00000485452  ENSG00000274175
# 11759452    DYNLL2  9606.ENSP00000477310         C17orf47
# 11759453    FAM65B  9606.ENSP00000482957         C6orf229
#
#                   Protein 2 ID  experiments  database  textmining  \
# 0         9606.ENSP00000272298            0         0           0
# 1         9606.ENSP00000272298            0         0           0
# 2         9606.ENSP00000272298            0         0           0
# 3         9606.ENSP00000272298            0         0         104
# 4         9606.ENSP00000272298          313         0           0
# ...                        ...          ...       ...         ...
# 11759449  9606.ENSP00000479378            0         0         560
# 11759450  9606.ENSP00000479378            0         0         556
# 11759451  9606.ENSP00000479378            0         0         559
# 11759452  9606.ENSP00000354874          212         0           0
# 11759453  9606.ENSP00000454913            0         0           0
#
#           Physical Combined Score
# 0                              41
# 1                              41
# 2                              41
# 3                             104
# 4                             313
# ...                           ...
# 11759449                      560
# 11759450                      556
# 11759451                      559
# 11759452                      212
# 11759453                       41
#
# [11759450 rows x 8 columns]
# 'proteins_interac_unique_ids'
#          Protein 1        Protein 2  experiments  database  textmining  \
# 0             ARF5            CALM2            0         0           0
# 1            FKBP4            CALM2            0         0           0
# 2          CYP51A1            CALM2            0         0           0
# 3             PDK4            CALM2            0         0         104
# 4             RALA            CALM2          313         0           0
# ...            ...              ...          ...       ...         ...
# 11759449    DUX4L7  ENSG00000274175            0         0         560
# 11759450      DUX4  ENSG00000274175            0         0         556
# 11759451    DUX4L8  ENSG00000274175            0         0         559
# 11759452    DYNLL2         C17orf47          212         0           0
# 11759453    FAM65B         C6orf229            0         0           0
#
#           Physical Combined Score  Max Physical Combined Score  \
# 0                              41                           41
# 1                              41                           41
# 2                              41                           41
# 3                             104                          104
# 4                             313                          313
# ...                           ...                          ...
# 11759449                      560                          560
# 11759450                      556                          556
# 11759451                      559                          559
# 11759452                      212                          212
# 11759453                       41                           41
#
#           Avg Physical Combined Score
# 0                                  41
# 1                                  41
# 2                                  41
# 3                                 104
# 4                                 313
# ...                               ...
# 11759449                          560
# 11759450                          556
# 11759451                          559
# 11759452                          212
# 11759453                           41
#
# [11743396 rows x 8 columns]
# 'proteins_interac_nonunique_ids'
#                 Protein 1          Protein 1 ID        Protein 2  \
# 720       ENSG00000258947  9606.ENSP00000320295            CALM2
# 1737      ENSG00000258947  9606.ENSP00000451560            CALM2
# 1816      ENSG00000243667  9606.ENSP00000477980            CALM2
# 2128      ENSG00000258947  9606.ENSP00000320295          ARHGEF9
# 2524      ENSG00000258947  9606.ENSP00000451560          ARHGEF9
# ...                   ...                   ...              ...
# 11724878            PADI6  9606.ENSP00000483125  ENSG00000239810
# 11724879          PRAMEF7  9606.ENSP00000484237  ENSG00000239810
# 11724880         PRAMEF25  9606.ENSP00000485258  ENSG00000239810
# 11724881           DUX4L8  9606.ENSP00000485452  ENSG00000239810
# 11724882         PRAMEF18  9606.ENSP00000485473  ENSG00000239810
#
#                   Protein 2 ID  experiments  database  textmining  \
# 720       9606.ENSP00000272298            0         0          94
# 1737      9606.ENSP00000272298            0         0          84
# 1816      9606.ENSP00000272298            0         0           0
# 2128      9606.ENSP00000253401            0         0           0
# 2524      9606.ENSP00000253401            0         0           0
# ...                        ...          ...       ...         ...
# 11724878  9606.ENSP00000480027            0         0         257
# 11724879  9606.ENSP00000480027            0         0           0
# 11724880  9606.ENSP00000480027            0         0           0
# 11724881  9606.ENSP00000480027            0         0         420
# 11724882  9606.ENSP00000480027            0         0           0
#
#           Physical Combined Score
# 720                            94
# 1737                           84
# 1816                           41
# 2128                           41
# 2524                           41
# ...                           ...
# 11724878                      256
# 11724879                       41
# 11724880                       41
# 11724881                      420
# 11724882                       41
#
# [16054 rows x 8 columns]
#              Protein 1        Protein 2  Protein 1 ID  Protein 2 ID  \
# 5269   ENSG00000258947  ENSG00000166160             3             3
# 1540   ENSG00000166160  ENSG00000258947             3             3
# 5415   ENSG00000258947            GFRA2             2             2
# 4717   ENSG00000258947           ANKS1B             2             2
# 8027             LETM1  ENSG00000183628             2             2
# ...                ...              ...           ...           ...
# 4086   ENSG00000243667          PRKAR1B             1             1
# 4085   ENSG00000243667          PRKAR1A             1             1
# 4084   ENSG00000243667           PRKACG             1             1
# 4083   ENSG00000243667           PRKACB             1             1
# 10829            ZUFSP  ENSG00000197054             1             1
#
#        experiments  database  textmining  Physical Combined Score
# 5269             3         3           3                        3
# 1540             3         3           3                        3
# 5415             2         2           2                        2
# 4717             2         2           2                        2
# 8027             2         2           2                        2
# ...            ...       ...         ...                      ...
# 4086             1         1           1                        1
# 4085             1         1           1                        1
# 4084             1         1           1                        1
# 4083             1         1           1                        1
# 10829            1         1           1                        1
#
# [10830 rows x 8 columns]
# 1    5608
# 2    5220
# 3       2
# Name: Physical Combined Score, dtype: int64
# 'corrected_proteins_interac_nonunique_ids'
#       Protein 1        Protein 2  experiments  database  textmining  \
# 0        339010  ENSG00000243667          NaN       NaN         NaN
# 1        339010  ENSG00000258947          NaN       NaN         NaN
# 2         AAMDC  ENSG00000243667          NaN       NaN         NaN
# 3         ABCA4  ENSG00000166160          NaN       NaN         NaN
# 4         ABCB1  ENSG00000258947          NaN       NaN         NaN
# ...         ...              ...          ...       ...         ...
# 10825   ZSCAN5A  ENSG00000239810          NaN       NaN         NaN
# 10826    ZSWIM3  ENSG00000197054          NaN       NaN         NaN
# 10827    ZSWIM3  ENSG00000239810          NaN       NaN         NaN
# 10828    ZSWIM7  ENSG00000166160          NaN       NaN         NaN
# 10829     ZUFSP  ENSG00000197054          NaN       NaN         NaN
#
#        Physical Combined Score  Max Physical Combined Score  \
# 0                          NaN                           41
# 1                          NaN                           41
# 2                          NaN                           41
# 3                          NaN                          145
# 4                          NaN                          329
# ...                        ...                          ...
# 10825                      NaN                          268
# 10826                      NaN                          214
# 10827                      NaN                          215
# 10828                      NaN                           41
# 10829                      NaN                          284
#
#        Avg Physical Combined Score
# 0                             41.0
# 1                             41.0
# 2                             41.0
# 3                            145.0
# 4                            307.5
# ...                            ...
# 10825                        267.0
# 10826                        214.0
# 10827                        213.5
# 10828                         41.0
# 10829                        284.0
#
# [10830 rows x 8 columns]
# 'string_score_df'
#       Protein 1        Protein 2  experiments  database  textmining  \
# 0          ARF5            CALM2          0.0       0.0         0.0
# 1         FKBP4            CALM2          0.0       0.0         0.0
# 2       CYP51A1            CALM2          0.0       0.0         0.0
# 3          PDK4            CALM2          0.0       0.0       104.0
# 4          RALA            CALM2        313.0       0.0         0.0
# ...         ...              ...          ...       ...         ...
# 10825   ZSCAN5A  ENSG00000239810          NaN       NaN         NaN
# 10826    ZSWIM3  ENSG00000197054          NaN       NaN         NaN
# 10827    ZSWIM3  ENSG00000239810          NaN       NaN         NaN
# 10828    ZSWIM7  ENSG00000166160          NaN       NaN         NaN
# 10829     ZUFSP  ENSG00000197054          NaN       NaN         NaN
#
#        Physical Combined Score  Max Physical Combined Score  \
# 0                         41.0                           41
# 1                         41.0                           41
# 2                         41.0                           41
# 3                        104.0                          104
# 4                        313.0                          313
# ...                        ...                          ...
# 10825                      NaN                          268
# 10826                      NaN                          214
# 10827                      NaN                          215
# 10828                      NaN                           41
# 10829                      NaN                          284
#
#        Avg Physical Combined Score
# 0                             41.0
# 1                             41.0
# 2                             41.0
# 3                            104.0
# 4                            313.0
# ...                            ...
# 10825                        267.0
# 10826                        214.0
# 10827                        213.5
# 10828                         41.0
# 10829                        284.0
#
# [11754226 rows x 8 columns]
# 'string_score_df'
#       Protein 1        Protein 2  experiments  database  textmining  \
# 0          ARF5            CALM2        0.000       0.0       0.000
# 1         FKBP4            CALM2        0.000       0.0       0.000
# 2       CYP51A1            CALM2        0.000       0.0       0.000
# 3          PDK4            CALM2        0.000       0.0       0.104
# 4          RALA            CALM2        0.313       0.0       0.000
# ...         ...              ...          ...       ...         ...
# 10825   ZSCAN5A  ENSG00000239810          NaN       NaN         NaN
# 10826    ZSWIM3  ENSG00000197054          NaN       NaN         NaN
# 10827    ZSWIM3  ENSG00000239810          NaN       NaN         NaN
# 10828    ZSWIM7  ENSG00000166160          NaN       NaN         NaN
# 10829     ZUFSP  ENSG00000197054          NaN       NaN         NaN
#
#        Physical Combined Score  Max Physical Combined Score  \
# 0                        0.041                        0.041
# 1                        0.041                        0.041
# 2                        0.041                        0.041
# 3                        0.104                        0.104
# 4                        0.313                        0.313
# ...                        ...                          ...
# 10825                      NaN                        0.268
# 10826                      NaN                        0.214
# 10827                      NaN                        0.215
# 10828                      NaN                        0.041
# 10829                      NaN                        0.284
#
#        Avg Physical Combined Score
# 0                           0.0410
# 1                           0.0410
# 2                           0.0410
# 3                           0.1040
# 4                           0.3130
# ...                            ...
# 10825                       0.2670
# 10826                       0.2140
# 10827                       0.2135
# 10828                       0.0410
# 10829                       0.2840
#
# [11754226 rows x 8 columns]
# Printing out counting statistics for entire filtering and correction process
# -----------------------------------------------------------------------------
# Number of Original Records: 11759454
# Number of Self-Interacting Protein Records: 4
# Number of Non-self Interacting Protein Records: 11759450
#
# Number of Records containing Non-self Interacting Unique Protein ID: 11743396
# Number of Records containing Non-self Interacting Non-unique Protein ID: 16054
# Number of Records containing Non-self Interacting Non-unique Protein ID (Corrected): 10830
#
# Number of Records in Final Table: 11754226
# Number of Records reduced: 5228
#
# Constructed and saved outputs/output_clean_string_score_table/string_score_table.csv
# Constructed and saved inputs/input_string_network_analysis/string_score_table.csv
# Constructed and saved inputs/input_filter_string_and_pathfx_score_tables/string_score_table.csv
# Finished Running clean_string_score_table.ipynb
#
# Running pathfx_network_analysis.ipynb ...
# 'pathfx_score_df'
#            source          target    weight
# 0       rs1042713   isoproterenol  0.233675
# 1       rs1042713  Ace Inhibitors  0.285181
# 2       rs1042713     Angiotensin  0.285181
# 3       rs1042713           Plain  0.285181
# 4       rs1042713     risperidone  0.285181
# ...           ...             ...       ...
# 273057     SFTPA1          SFTPA2  0.359348
# 273058       VCAN            SELL  0.279930
# 273059       SELP            VCAN  0.279930
# 273060       NFIB            NFIC  0.279930
# 273061       NFIX            NFIB  0.279930
#
# [273062 rows x 3 columns]
# Outputting Number of Distinct Proteins
# ------------------------------------------------
# Number of Unique sources: 23970
# Number of Unique targets: 23970
# Number of Unique sources and targets: 23970
# 'pathfx_source_to_target_weight_stats_df'
#                source  count      mean       std       max       min  \
# 15441             UBC   6753  0.528777  0.132470  0.935012  0.279930
# 695               APP   1984  0.287942  0.040666  0.705007  0.246744
# 13900           SUMO2    713  0.429295  0.086484  0.818355  0.246936
# 14904            TP53    627  0.417612  0.124118  0.990000  0.246936
# 23067             tat    502  0.321185  0.081879  0.770889  0.246744
# ...               ...    ...       ...       ...       ...       ...
# 12591           SAMD1      1  0.323872       NaN  0.323872  0.323872
# 12590            SAM1      1  0.279930       NaN  0.279930  0.279930
# 12589           SAM-2      1  0.279930       NaN  0.279930  0.279930
# 12588           SALL4      1  0.380279       NaN  0.380279  0.380279
# 23969  zuclopenthixol      1  0.285181       NaN  0.285181  0.285181
#
#                sum
# 15441  3570.832522
# 695     571.276135
# 13900   306.087256
# 14904   261.842982
# 23067   161.235009
# ...            ...
# 12591     0.323872
# 12590     0.279930
# 12589     0.279930
# 12588     0.380279
# 23969     0.285181
#
# [23970 rows x 7 columns]
# 'pathfx_num_target_per_source_stats_df'
#        Number Target Interacton Per Source
# count                         23970.000000
# mean                             11.391823
# std                              51.499400
# max                            6753.000000
# min                               1.000000
# sum                          273062.000000
# 'pathfx_num_interac_distribution_df'
#      Number of Protein Interactions  count
# 0                                 1   5548
# 1                                 2   3582
# 2                                 3   3276
# 3                                 4   1710
# 4                                 5   1148
# ..                              ...    ...
# 191                             326      1
# 190                             280      1
# 189                             318      1
# 188                             281      1
# 238                            6753      1
#
# [239 rows x 2 columns]
# 'pathfx_edge_score_distribution_df'
#       Edge Score  count
# 0       0.279930  38181
# 1       0.323872  18816
# 2       0.380279  11701
# 3       0.471716  11610
# 4       0.346946   7669
# ...          ...    ...
# 729     0.690513      1
# 728     0.698414      1
# 727     0.681025      1
# 726     0.775171      1
# 1101    0.894947      1
#
# [1102 rows x 2 columns]
# 'pathfx_removed_cross_pair_df'
#            source          target    weight
# 7       rs1042713  spironolactone  0.285181
# 10      rs1042713      salbutamol  0.659492
# 12      rs1042713      salmeterol  0.659492
# 13      rs1042713      tiotropium  0.285181
# 20      rs1042714     terbutaline  0.233675
# ...           ...             ...       ...
# 273052      STAT1           STAT3  0.354509
# 273053      STAT1           STAT2  0.305411
# 273057     SFTPA1          SFTPA2  0.359348
# 273059       SELP            VCAN  0.279930
# 273060       NFIB            NFIC  0.279930
#
# [136531 rows x 3 columns]
# 'pathfx_all_weight_stats_df'
#               weight
# count  136531.000000
# mean        0.386598
# std         0.131861
# max         0.990000
# min         0.233675
# sum     52782.576648
# Constructed and saved outputs/output_pathfx_network_analysis/csv_files/pathfx_score_table.csv
# Constructed and saved outputs/output_pathfx_network_analysis/csv_files/pathfx_all_weight_stats_table.csv
# Constructed and saved outputs/output_pathfx_network_analysis/csv_files/pathfx_num_target_per_source_stats_table.csv
# Constructed and saved outputs/output_pathfx_network_analysis/csv_files/pathfx_source_to_target_weight_stats.csv
# Constructed and saved outputs/output_pathfx_network_analysis/csv_files/pathfx_num_interac_distribution_table.csv
# Constructed and saved outputs/output_pathfx_network_analysis/csv_files/pathfx_removed_cross_pair_pathfx_table.csv
# Constructed and saved outputs/output_pathfx_network_analysis/visual_graphs/Distribution of the Number of Protein Interactions per Protein in PathFX_histplot.png
# Constructed and saved outputs/output_pathfx_network_analysis/visual_graphs/Distribution of the Number of Protein Interactions per Protein in PathFX (Zoomed)_histplot.png
# Constructed and saved outputs/output_pathfx_network_analysis/visual_graphs/Distribution of the Number of Protein Interactions per Protein in PathFX (Zoomed 2x)_histplot.png
# Constructed and saved outputs/output_pathfx_network_analysis/visual_graphs/Distribution of edge scores in PathFX_histplot.png
# Constructed and saved outputs/output_pathfx_network_analysis/visual_graphs/Distribution of edge scores in PathFX (Zoomed)_histplot.png
#
# PathFX Interactome
# -------------------------------------------
# Number of Unique sources: 23970
# Number of Unique targets: 23970
# Number of Unique sources and targets: 23970
#
#
# Constructing Network graph for Protein-Protein Combined score interaction (Avg Physical Combined Score)
#
#
# Saving Constructed Network graph for PathFX
#
# PathFX NetworkX Interactome Graph
# -------------------------------------
# Number of Nodes: 23970
# Number of Edges: 136531
#
# Average node degree: 11.391823112223612
# Standard Deviation node degree: 51.499400414332904
# Max node degree: 6753.0
# Min node degree: 1.0
#
# Average edge weight: 0.3865977444499079
# Standard Deviation node degree: 0.13186136402093826
# Max edge weight: 0.99
# Min edge weight: 0.2336752003400327
#
# nx Graph is connected - False
# Number of Connected Components: 116
#
# Top 25 Proteins with Most Neighbors - Weighted Edge Scores
# -------------------------------------------------------------------------------------
#           source  count      mean       std       max       min          sum
# 15441        UBC   6753  0.528777  0.132470  0.935012  0.279930  3570.832522
# 695          APP   1984  0.287942  0.040666  0.705007  0.246744   571.276135
# 13900      SUMO2    713  0.429295  0.086484  0.818355  0.246936   306.087256
# 14904       TP53    627  0.417612  0.124118  0.990000  0.246936   261.842982
# 23067        tat    502  0.321185  0.081879  0.770889  0.246744   161.235009
# 4310        EGFR    428  0.411818  0.127012  0.990000  0.246936   176.258227
# 4484       EP300    418  0.396489  0.119200  0.831286  0.246936   165.732220
# 1506       BRCA1    407  0.385077  0.124197  0.832451  0.246744   156.726326
# 6113       HDAC1    394  0.424392  0.121547  0.990000  0.246936   167.210341
# 5809        GRB2    392  0.361033  0.091608  0.743959  0.279930   141.524839
# 15467      UBE2I    387  0.347021  0.097861  0.990000  0.246936   134.297148
# 3138     CSNK2A1    362  0.329635  0.076515  0.691677  0.246936   119.327712
# 13899      SUMO1    352  0.403492  0.091153  0.785320  0.246936   142.029252
# 4586        ESR1    352  0.414969  0.138258  0.990000  0.246936   146.069250
# 7523       KRT40    341  0.393193  0.096163  0.593777  0.279930   134.078956
# 8357        MDM2    326  0.431508  0.127941  0.872160  0.279641   140.671651
# 13662        SRC    318  0.386717  0.103964  0.745886  0.246936   122.976079
# 5691      GOLGA2    312  0.398331  0.097605  0.638448  0.246936   124.279199
# 6529    HSP90AA1    309  0.406634  0.114617  0.816383  0.279930   125.649811
# 14956      TRAF2    308  0.403022  0.110303  0.858890  0.279930   124.130628
# 4167        Dlg4    297  0.284500  0.033757  0.703476  0.246936    84.496410
# 3196      CTNNB1    284  0.428168  0.123251  0.990000  0.279641   121.599799
# 7548   KRTAP10-3    281  0.279930  0.000000  0.279930  0.279930    78.660447
# 3055      CREBBP    280  0.389392  0.101388  0.816659  0.246936   109.029691
# 6793       IKBKG    279  0.363579  0.129515  0.990000  0.279930   101.438559
#
# Constructed and saved inputs/input_comparison_network_analysis/pathfx/pathfx_G.gpickle
# Constructed and saved inputs/input_comparison_network_analysis/pathfx/pathfx_score_table.csv
# Constructed and saved inputs/input_comparison_network_analysis/pathfx/pathfx_num_target_per_source_stats_table.csv
# Constructed and saved inputs/input_comparison_network_analysis/pathfx/pathfx_removed_cross_pair_pathfx_table.csv
# Constructed and saved inputs/input_comparison_network_analysis/pathfx/pathfx_all_weight_stats_table.csv
# Constructed and saved inputs/input_comparison_network_analysis/pathfx/pathfx_source_to_target_weight_stats_table.csv
# Finished Running pathfx_network_analysis.ipynb
#
# Running string_network_analysis.ipynb ...
# 'string_score_df'
#          Protein 1        Protein 2  experiments  database  textmining  \
# 0             ARF5            CALM2        0.000       0.0       0.000
# 1            FKBP4            CALM2        0.000       0.0       0.000
# 2          CYP51A1            CALM2        0.000       0.0       0.000
# 3             PDK4            CALM2        0.000       0.0       0.104
# 4             RALA            CALM2        0.313       0.0       0.000
# ...            ...              ...          ...       ...         ...
# 11754221   ZSCAN5A  ENSG00000239810          NaN       NaN         NaN
# 11754222    ZSWIM3  ENSG00000197054          NaN       NaN         NaN
# 11754223    ZSWIM3  ENSG00000239810          NaN       NaN         NaN
# 11754224    ZSWIM7  ENSG00000166160          NaN       NaN         NaN
# 11754225     ZUFSP  ENSG00000197054          NaN       NaN         NaN
#
#           Physical Combined Score  Max Physical Combined Score  \
# 0                           0.041                        0.041
# 1                           0.041                        0.041
# 2                           0.041                        0.041
# 3                           0.104                        0.104
# 4                           0.313                        0.313
# ...                           ...                          ...
# 11754221                      NaN                        0.268
# 11754222                      NaN                        0.214
# 11754223                      NaN                        0.215
# 11754224                      NaN                        0.041
# 11754225                      NaN                        0.284
#
#           Avg Physical Combined Score
# 0                              0.0410
# 1                              0.0410
# 2                              0.0410
# 3                              0.1040
# 4                              0.3130
# ...                               ...
# 11754221                       0.2670
# 11754222                       0.2140
# 11754223                       0.2135
# 11754224                       0.0410
# 11754225                       0.2840
#
# [11754226 rows x 8 columns]
# 'string_num_protein_per_protein_stats_df'
#        Number Protein Interaction Per Protein
# count                            1.934400e+04
# mean                             6.076420e+02
# std                              5.287327e+02
# max                              7.644000e+03
# min                              1.000000e+00
# sum                              1.175423e+07
# 'string_removed_cross_pair_df'
#                 Protein 1 Protein 2  experiments  database  textmining  \
# 0                    ARF5     CALM2          0.0       0.0       0.000
# 18                 ACTL6B     CALM2          0.0       0.0       0.000
# 26                   AQP2     CALM2          0.0       0.0       0.051
# 31                   APOH     CALM2          0.0       0.0       0.000
# 40                ANKRD54     CALM2          0.0       0.0       0.210
# ...                   ...       ...          ...       ...         ...
# 11750292  ENSG00000258947    ZNF445          NaN       NaN         NaN
# 11750293  ENSG00000258947    ZNF516          NaN       NaN         NaN
# 11750294  ENSG00000258947    ZNF607          NaN       NaN         NaN
# 11750295  ENSG00000258947     ZNRF1          NaN       NaN         NaN
# 11750296  ENSG00000258947     ZNRF2          NaN       NaN         NaN
#
#           Physical Combined Score  Max Physical Combined Score  \
# 0                           0.041                        0.041
# 18                          0.041                        0.041
# 26                          0.050                        0.050
# 31                          0.041                        0.041
# 40                          0.210                        0.210
# ...                           ...                          ...
# 11750292                      NaN                        0.138
# 11750293                      NaN                        0.093
# 11750294                      NaN                        0.169
# 11750295                      NaN                        0.041
# 11750296                      NaN                        0.041
#
#           Avg Physical Combined Score
# 0                              0.0410
# 18                             0.0410
# 26                             0.0500
# 31                             0.0410
# 40                             0.2100
# ...                               ...
# 11750292                       0.0895
# 11750293                       0.0875
# 11750294                       0.1595
# 11750295                       0.0410
# 11750296                       0.0410
#
# [5877113 rows x 8 columns]
# 'string_all_max_physical_combined_scores_stats_df'
#        Max Physical Combined Score
# count                 5.877113e+06
# mean                  1.836416e-01
# std                   2.219951e-01
# max                   9.990000e-01
# min                   4.100000e-02
# sum                   1.079283e+06
# 'string_all_avg_physical_combined_scores_stats_df'
#        Avg Physical Combined Score
# count                 5.877113e+06
# mean                  1.836376e-01
# std                   2.219929e-01
# max                   9.990000e-01
# min                   4.100000e-02
# sum                   1.079259e+06
# Constructed and saved outputs/output_string_network_analysis/csv_files/string_score_table.csv
# Constructed and saved outputs/output_string_network_analysis/csv_files/string_num_protein_per_protein_stats_table.csv
# Constructed and saved outputs/output_string_network_analysis/csv_files/string_removed_cross_pair_table.csv
# Constructed and saved outputs/output_string_network_analysis/csv_files/string_all_max_physical_combined_scores_stats_table.csv
# Constructed and saved outputs/output_string_network_analysis/csv_files/string_all_avg_physical_combined_scores_stats_table.csv
# Constructed and saved outputs/output_string_network_analysis/csv_files/summary_scores/string_summary_score_stats_for_experiments_per_protein.csv
# Constructed and saved outputs/output_string_network_analysis/csv_files/summary_scores/string_summary_score_stats_for_database_per_protein.csv
# Constructed and saved outputs/output_string_network_analysis/csv_files/summary_scores/string_summary_score_stats_for_textmining_per_protein.csv
# Constructed and saved outputs/output_string_network_analysis/csv_files/summary_scores/string_summary_score_stats_for_Physical Combined Score_per_protein.csv
# Constructed and saved outputs/output_string_network_analysis/csv_files/summary_scores/string_summary_score_stats_for_Max Physical Combined Score_per_protein.csv
# Constructed and saved outputs/output_string_network_analysis/csv_files/summary_scores/string_summary_score_stats_for_Avg Physical Combined Score_per_protein.csv
# Constructed and saved outputs/output_string_network_analysis/visual_graphs/Disribution of experiments in STRING_histplot.png
# Constructed and saved outputs/output_string_network_analysis/visual_graphs/Disribution of database in STRING_histplot.png
# Constructed and saved outputs/output_string_network_analysis/visual_graphs/Disribution of textmining in STRING_histplot.png
# Constructed and saved outputs/output_string_network_analysis/visual_graphs/Disribution of Physical Combined Score in STRING_histplot.png
# Constructed and saved outputs/output_string_network_analysis/visual_graphs/Disribution of Max Physical Combined Score in STRING_histplot.png
# Constructed and saved outputs/output_string_network_analysis/visual_graphs/Disribution of Avg Physical Combined Score in STRING_histplot.png
# Constructed and saved outputs/output_string_network_analysis/visual_graphs/Disribution of Avg Physical Combined Score in STRING (ZOOMED LEFT)_histplot.png
# Constructed and saved outputs/output_string_network_analysis/visual_graphs/Disribution of Avg Physical Combined Score in STRING (ZOOMED RIGHT)_histplot.png
# Constructed and saved outputs/output_string_network_analysis/visual_graphs/Distribution of the Number of Protein Interactions per Protein in STRING_histplot.png
# 'string_summary_score_stats_for_avg_physical_combined_score_df'
#             Protein ID  count      mean       std    max    min        sum
# 0                GAPDH   7644  0.241637  0.150712  0.994  0.041  1847.0700
# 1                 AKT1   6507  0.300910  0.222489  0.999  0.041  1958.0225
# 2                 TP53   6193  0.354423  0.240752  0.999  0.041  2194.9425
# 3                  INS   6053  0.320572  0.201611  0.998  0.041  1940.4200
# 4                  MYC   5786  0.294266  0.186558  0.999  0.041  1702.6225
# ...                ...    ...       ...       ...    ...    ...        ...
# 19339            PGBD3      1  0.532000       NaN  0.532  0.532     0.5320
# 19340          CCDC179      1  0.198000       NaN  0.198  0.198     0.1980
# 19341         FAM90A26      1  0.955000       NaN  0.955  0.955     0.9550
# 19342         C18orf42      1  0.196000       NaN  0.196  0.196     0.1960
# 19343  ENSG00000259171      1  0.041000       NaN  0.041  0.041     0.0410
#
# [19344 rows x 7 columns]
# STRING Database
# -------------------------------------------
# Number of Unique Protein 1s: 19344
# Number of Unique Protein 2s: 19344
# Number of Unique Protein: 19344
#
#
# Constructing Network graph for Protein-Protein Combined score interaction (Avg Physical Combined Score)
#
# Saving Constructed Network graph for Protein-Protein Combined score interaction (Avg Physical Combined Score)
#
# STRING Database NetworkX Graph
# -------------------------------------
# Number of Nodes: 19344
# Number of Edges: 5877113
# Average node degree: 607.6419561621175
# Standard Deviation node degree: 528.732679726321
# Max node degree: 7644.0
# Min node degree: 1.0
# Average edge weight: 0.18363761665666914
# Standard Deviation node degree: 0.2219928864881866
# Max edge weight: 0.999
# Min edge weight: 0.041
# nx Graph is connected - True
# Number of Connected Components: 1
#
# Top 25 Proteins with Most Neighbors - Avg Physical Combined Scored
# -------------------------------------------------------------------------------------
#    Protein ID  count      mean       std    max    min        sum
# 0       GAPDH   7644  0.241637  0.150712  0.994  0.041  1847.0700
# 1        AKT1   6507  0.300910  0.222489  0.999  0.041  1958.0225
# 2        TP53   6193  0.354423  0.240752  0.999  0.041  2194.9425
# 3         INS   6053  0.320572  0.201611  0.998  0.041  1940.4200
# 4         MYC   5786  0.294266  0.186558  0.999  0.041  1702.6225
# 5        HRAS   5630  0.247494  0.214646  0.998  0.041  1393.3930
# 6         ALB   5425  0.286800  0.181702  0.992  0.041  1555.8900
# 7       MAPK3   5269  0.248985  0.233512  0.999  0.041  1311.9045
# 8        EGFR   5156  0.300841  0.232236  0.999  0.041  1551.1375
# 9       LRRK2   4858  0.097913  0.124326  0.962  0.041   475.6625
# 10        TNF   4766  0.294572  0.206300  0.999  0.041  1403.9300
# 11      MAPK1   4703  0.261218  0.262223  0.999  0.041  1228.5080
# 12       ACTB   4606  0.231971  0.200861  0.996  0.041  1068.4600
# 13        SRC   4588  0.293880  0.248988  0.999  0.041  1348.3230
# 14        EGF   4480  0.314854  0.220550  0.999  0.041  1410.5440
# 15   HSP90AA1   4268  0.241845  0.239994  0.996  0.041  1032.1950
# 16     NOTCH1   4207  0.272807  0.190814  0.999  0.041  1147.6990
# 17       PTEN   4164  0.253471  0.203714  0.997  0.041  1055.4540
# 18        JUN   4159  0.285406  0.223273  0.999  0.041  1187.0055
# 19     RNASEL   4157  0.075232  0.116224  0.983  0.041   312.7390
# 20        IL6   4118  0.339376  0.221689  0.999  0.041  1397.5490
# 21      HDAC1   4047  0.213653  0.247289  0.999  0.041   864.6535
# 22        FN1   3983  0.304662  0.219484  0.995  0.041  1213.4705
# 23      CASP3   3958  0.276528  0.190892  0.999  0.041  1094.4970
# 24     CDKN2A   3938  0.235645  0.169439  0.998  0.041   927.9715
#
# Constructed and saved inputs/input_comparison_network_analysis/string/string_G.gpickle
# Constructed and saved inputs/input_comparison_network_analysis/string/string_score_table.csv
# Constructed and saved inputs/input_comparison_network_analysis/string/string_num_protein_per_protein_stats_table.csv
# Constructed and saved inputs/input_comparison_network_analysis/string/string_removed_cross_pair_table.csv
# Constructed and saved inputs/input_comparison_network_analysis/string/string_all_avg_physical_combined_scores_stats_table.csv
# Constructed and saved inputs/input_comparison_network_analysis/string/string_summary_score_stats_for_Avg.csv
# Constructed and saved inputs/input_comparison_network_analysis/string/string_summary_score_stats_for_Avg Physical Combined Score_per_protein.csv
# Finished Running string_network_analysis.ipynb
#
# Running comparison_network_analysis.ipynb ...
# 'string_score_df'
#          Protein 1        Protein 2  experiments  database  textmining  \
# 0             ARF5            CALM2        0.000       0.0       0.000
# 1            FKBP4            CALM2        0.000       0.0       0.000
# 2          CYP51A1            CALM2        0.000       0.0       0.000
# 3             PDK4            CALM2        0.000       0.0       0.104
# 4             RALA            CALM2        0.313       0.0       0.000
# ...            ...              ...          ...       ...         ...
# 11754221   ZSCAN5A  ENSG00000239810          NaN       NaN         NaN
# 11754222    ZSWIM3  ENSG00000197054          NaN       NaN         NaN
# 11754223    ZSWIM3  ENSG00000239810          NaN       NaN         NaN
# 11754224    ZSWIM7  ENSG00000166160          NaN       NaN         NaN
# 11754225     ZUFSP  ENSG00000197054          NaN       NaN         NaN
#
#           Physical Combined Score  Max Physical Combined Score  \
# 0                           0.041                        0.041
# 1                           0.041                        0.041
# 2                           0.041                        0.041
# 3                           0.104                        0.104
# 4                           0.313                        0.313
# ...                           ...                          ...
# 11754221                      NaN                        0.268
# ...
# Constructed and saved outputs/output_string_network_analysis/visual_graphs/Distribution of the Number of Protein Interactions per Protein in STRING (ZOOMED)_histplot.png
# 'string_summary_score_stats_for_avg_physical_combined_score_df'
#       Protein ID  count      mean       std    max    min        sum
# 0          GAPDH   7644  0.241637  0.150712  0.994  0.041  1847.0700
# 1           AKT1   6507  0.300910  0.222489  0.999  0.041  1958.0225
# 2           TP53   6193  0.354423  0.240752  0.999  0.041  2194.9425
# 3            INS   6053  0.320572  0.201611  0.998  0.041  1940.4200
# 4            MYC   5786  0.294266  0.186558  0.999  0.041  1702.6225
# ...          ...    ...       ...       ...    ...    ...        ...
# 19333   C17orf47      1  0.212000       NaN  0.212  0.212     0.2120
# 19334    CCDC142      1  0.041000       NaN  0.041  0.041     0.0410
# 19335    C5orf55      1  0.309000       NaN  0.309  0.309     0.3090
# 19336     CLPSL2      1  0.556000       NaN  0.556  0.556     0.5560
# 19337   C10orf95      1  0.379000       NaN  0.379  0.379     0.3790
#
# [19338 rows x 7 columns]
# STRING Database
# -------------------------------------------
# Number of Unique Protein 1s: 19338
# Number of Unique Protein 2s: 19338
# Number of Unique Protein: 19338
#
#
# Constructing Network graph for Protein-Protein Combined score interaction (Avg Physical Combined Score)
#
# Saving Constructed Network graph for Protein-Protein Combined score interaction (Avg Physical Combined Score)
#
# STRING Database NetworkX Graph
# -------------------------------------
# Number of Nodes: 19338
# Number of Edges: 5692702
# Average node degree: 588.7580928741338
# Standard Deviation node degree: 530.8547488309175
# Max node degree: 7644.0
# Min node degree: 1.0
# Average edge weight: 0.1836058763441498
# Standard Deviation node degree: 0.22232178512697068
# Max edge weight: 0.999
# Min edge weight: 0.041
# nx Graph is connected - True
# Number of Connected Components: 1
#
# Top 25 Proteins with Most Neighbors - Avg Physical Combined Scored
# -------------------------------------------------------------------------------------
#    Protein ID  count      mean       std    max    min        sum
# 0       GAPDH   7644  0.241637  0.150712  0.994  0.041  1847.0700
# 1        AKT1   6507  0.300910  0.222489  0.999  0.041  1958.0225
# 2        TP53   6193  0.354423  0.240752  0.999  0.041  2194.9425
# 3         INS   6053  0.320572  0.201611  0.998  0.041  1940.4200
# 4         MYC   5786  0.294266  0.186558  0.999  0.041  1702.6225
# 5        HRAS   5630  0.247494  0.214646  0.998  0.041  1393.3930
# 6         ALB   5425  0.286800  0.181702  0.992  0.041  1555.8900
# 7       MAPK3   5269  0.248985  0.233512  0.999  0.041  1311.9045
# 8        EGFR   5156  0.300841  0.232236  0.999  0.041  1551.1375
# 9       LRRK2   4858  0.097913  0.124326  0.962  0.041   475.6625
# 10        TNF   4766  0.294572  0.206300  0.999  0.041  1403.9300
# 11      MAPK1   4703  0.261218  0.262223  0.999  0.041  1228.5080
# 12       ACTB   4606  0.231971  0.200861  0.996  0.041  1068.4600
# 13        SRC   4588  0.293880  0.248988  0.999  0.041  1348.3230
# 14        EGF   4480  0.314854  0.220550  0.999  0.041  1410.5440
# 15   HSP90AA1   4268  0.241845  0.239994  0.996  0.041  1032.1950
# 16     NOTCH1   4207  0.272807  0.190814  0.999  0.041  1147.6990
# 17       PTEN   4164  0.253471  0.203714  0.997  0.041  1055.4540
# 18        JUN   4159  0.285406  0.223273  0.999  0.041  1187.0055
# 19     RNASEL   4157  0.075232  0.116224  0.983  0.041   312.7390
# 20        IL6   4118  0.339376  0.221689  0.999  0.041  1397.5490
# 21      HDAC1   4047  0.213653  0.247289  0.999  0.041   864.6535
# 22        FN1   3983  0.304662  0.219484  0.995  0.041  1213.4705
# 23      CASP3   3958  0.276528  0.190892  0.999  0.041  1094.4970
# 24     CTNNB1   3938  0.287099  0.252422  0.999  0.041  1130.5965
#
# Constructed and saved inputs/input_comparison_network_analysis/string/string_G.gpickle
# Constructed and saved inputs/input_comparison_network_analysis/string/string_score_table.csv
# Constructed and saved inputs/input_comparison_network_analysis/string/string_num_protein_per_protein_stats_table.csv
# Constructed and saved inputs/input_comparison_network_analysis/string/string_removed_cross_pair_table.csv
# Constructed and saved inputs/input_comparison_network_analysis/string/string_all_avg_physical_combined_scores_stats_table.csv
# Constructed and saved inputs/input_comparison_network_analysis/string/string_summary_score_stats_for_Avg.csv
# Constructed and saved inputs/input_comparison_network_analysis/string/string_summary_score_stats_for_Avg Physical Combined Score_per_protein.csv
# Finished Running string_network_analysis.ipynb
#
# Running comparison_network_analysis.ipynb ...
# 'string_score_df'
#                 Protein 1 Protein 2  experiments  database  textmining  \
# 0                    ARF5     CALM2        0.000       0.0       0.000
# 1                   FKBP4     CALM2        0.000       0.0       0.000
# 2                 CYP51A1     CALM2        0.000       0.0       0.000
# 3                    PDK4     CALM2        0.000       0.0       0.104
# 4                    RALA     CALM2        0.313       0.0       0.000
# ...                   ...       ...          ...       ...         ...
# 11385399  ENSG00000258947    ZNF445          NaN       NaN         NaN
# 11385400  ENSG00000258947    ZNF516          NaN       NaN         NaN
# 11385401  ENSG00000258947    ZNF607          NaN       NaN         NaN
# 11385402  ENSG00000258947     ZNRF1          NaN       NaN         NaN
# 11385403  ENSG00000258947     ZNRF2          NaN       NaN         NaN
#
#           Physical Combined Score  Max Physical Combined Score  \
# 0                           0.041                        0.041
# 1                           0.041                        0.041
# 2                           0.041                        0.041
# 3                           0.104                        0.104
# 4                           0.313                        0.313
# ...                           ...                          ...
# 11385399                      NaN                        0.138
# 11385400                      NaN                        0.093
# 11385401                      NaN                        0.169
# 11385402                      NaN                        0.041
# 11385403                      NaN                        0.041
#
#           Avg Physical Combined Score
# 0                              0.0410
# 1                              0.0410
# 2                              0.0410
# 3                              0.1040
# 4                              0.3130
# ...                               ...
# 11385399                       0.0895
# 11385400                       0.0875
# 11385401                       0.1595
# 11385402                       0.0410
# 11385403                       0.0410
#
# [11385404 rows x 8 columns]
# 'string_num_protein_per_protein_stats_df'
#        Number Protein Interaction Per Protein
# count                            1.933800e+04
# mean                             5.887581e+02
# std                              5.308547e+02
# max                              7.644000e+03
# min                              1.000000e+00
# sum                              1.138540e+07
# 'string_removed_cross_pair_df'
#                Protein 1 Protein 2  experiments  database  textmining  \
# 0                   ARF5     CALM2          0.0       0.0       0.000
# 1                 ACTL6B     CALM2          0.0       0.0       0.000
# 2                   AQP2     CALM2          0.0       0.0       0.051
# 3                   APOH     CALM2          0.0       0.0       0.000
# 4                ANKRD54     CALM2          0.0       0.0       0.210
# ...                  ...       ...          ...       ...         ...
# 5692697  ENSG00000258947    ZNF445          NaN       NaN         NaN
# 5692698  ENSG00000258947    ZNF516          NaN       NaN         NaN
# 5692699  ENSG00000258947    ZNF607          NaN       NaN         NaN
# 5692700  ENSG00000258947     ZNRF1          NaN       NaN         NaN
# 5692701  ENSG00000258947     ZNRF2          NaN       NaN         NaN
#
#          Physical Combined Score  Max Physical Combined Score  \
# 0                          0.041                        0.041
# 1                          0.041                        0.041
# 2                          0.050                        0.050
# 3                          0.041                        0.041
# 4                          0.210                        0.210
# ...                          ...                          ...
# 5692697                      NaN                        0.138
# 5692698                      NaN                        0.093
# 5692699                      NaN                        0.169
# 5692700                      NaN                        0.041
# 5692701                      NaN                        0.041
#
#          Avg Physical Combined Score
# 0                             0.0410
# 1                             0.0410
# 2                             0.0500
# 3                             0.0410
# 4                             0.2100
# ...                              ...
# 5692697                       0.0895
# 5692698                       0.0875
# 5692699                       0.1595
# 5692700                       0.0410
# 5692701                       0.0410
#
# [5692702 rows x 8 columns]
# 'string_all_avg_physical_combined_scores_stats_df'
#        Avg Physical Combined Score
# count                 5.692702e+06
# mean                  1.836059e-01
# std                   2.223218e-01
# max                   9.990000e-01
# min                   4.100000e-02
# sum                   1.045214e+06
# 'string_summary_score_stats_for_avg_physical_combined_score_df'
#       Protein ID  count      mean       std    max    min        sum
# 0          GAPDH   7644  0.241637  0.150712  0.994  0.041  1847.0700
# 1           AKT1   6507  0.300910  0.222489  0.999  0.041  1958.0225
# 2           TP53   6193  0.354423  0.240752  0.999  0.041  2194.9425
# 3            INS   6053  0.320572  0.201611  0.998  0.041  1940.4200
# 4            MYC   5786  0.294266  0.186558  0.999  0.041  1702.6225
# ...          ...    ...       ...       ...    ...    ...        ...
# 19333   C17orf47      1  0.212000       NaN  0.212  0.212     0.2120
# 19334    CCDC142      1  0.041000       NaN  0.041  0.041     0.0410
# 19335    C5orf55      1  0.309000       NaN  0.309  0.309     0.3090
# 19336     CLPSL2      1  0.556000       NaN  0.556  0.556     0.5560
# 19337   C10orf95      1  0.379000       NaN  0.379  0.379     0.3790
#
# [19338 rows x 7 columns]
# 'pathfx_score_df'
#                   source    target    weight
# 0                 CHMP1B    KNSTRN  0.279930
# 1                 CHMP1B      USP8  0.562588
# 2                 CHMP1B    STAMBP  0.676545
# 3                 CHMP1B     SPAST  0.416595
# 4                 CHMP1B  SNRNP200  0.279930
# ...                  ...       ...       ...
# 262235               tat      GPX2  0.246744
# 262236               tat      GPX5  0.246744
# 262237               tat      GPX6  0.246744
# 262238               tat     BRIX1  0.279930
# 262239  uniprotkb:I6L9F6      USP2  0.471716
#
# [262240 rows x 3 columns]
# 'pathfx_num_target_per_source_stats_df'
#        Number Target Interacton Per Source
# count                         22832.000000
# mean                             11.485634
# std                              52.692758
# max                            6753.000000
# min                               1.000000
# sum                          262240.000000
# 'pathfx_removed_cross_pair_df'
#             source    target    weight
# 0           CHMP1B    KNSTRN  0.279930
# 1           CHMP1B      USP8  0.562588
# 2           CHMP1B    STAMBP  0.676545
# 3           CHMP1B     SPAST  0.416595
# 4           CHMP1B  SNRNP200  0.279930
# ...            ...       ...       ...
# 131115        Ppif     VDAC1  0.279930
# 131116      ADGRG1     ADRB2  0.490794
# 131117       ORF26    TRIM37  0.279930
# 131118  ALL3_AEDAE    COL3A1  0.416595
# 131119       ORF28     STX17  0.279930
#
# [131120 rows x 3 columns]
# 'pathfx_all_weight_stats_df'
#               weight
# count  131120.000000
# mean        0.387541
# std         0.131891
# max         0.990000
# min         0.244958
# sum     50814.314438
# 'pathfx_source_to_target_weight_stats_df'
#        source  count      mean       std       max       min          sum
# 0         UBC   6753  0.528777  0.132470  0.935012  0.279930  3570.832522
# 1         APP   1984  0.287942  0.040666  0.705007  0.246744   571.276135
# 2       SUMO2    713  0.429295  0.086484  0.818355  0.246936   306.087256
# 3        TP53    627  0.417612  0.124118  0.990000  0.246936   261.842982
# 4         tat    436  0.321098  0.085697  0.770889  0.246744   139.998813
# ...       ...    ...       ...       ...       ...       ...          ...
# 22827    RTTN      1  0.605763       NaN  0.605763  0.605763     0.605763
# 22828  RTT109      1  0.416595       NaN  0.416595  0.416595     0.416595
# 22829    RTP2      1  0.279930       NaN  0.279930  0.279930     0.279930
# 22830  RTFDC1      1  0.279930       NaN  0.279930  0.279930     0.279930
# 22831    yqeH      1  0.380279       NaN  0.380279  0.380279     0.380279
#
# [22832 rows x 7 columns]
# STRING Database
# -------------------------------------------
# Number of Unique Protein 1s: 19338
# Number of Unique Protein 2s: 19338
# Number of Unique Protein: 19338
#
#
# PathFX Interactome
# -------------------------------------------
# Number of Unique sources: 22832
# Number of Unique targets: 22832
# Number of Unique sources and targets: 22832
#
#
# Both STRING and PathFX
# ----------------------------------------------------------------
# Number of Shared Common Nodes from both graph networks: 13948
# Number of distinct STRING nodes: 5390
# Number of distinct PathFX nodes: 8884
#
#
# Comparison of NODES in STRING and PathFX NetworkX Graphs
# ----------------------------------------------------------------
# Number of Shared Common Nodes from both graph networks: 13948
# Number of distinct STRING nodes: 5390
# Number of distinct PathFX nodes: 8884
#
#
# Comparison of EDGES in STRING and PathFX NetworkX Graphs
# ----------------------------------------------------------------
# Number of Shared Common Edges from both graph networks: 72278
# Number of distinct STRING edges: 5620424
# Number of distinct PathFX edges: 58842
#
# Constructed and saved outputs/output_comparison_network_analysis/visual_graphs/Distribution of edge scores in STRING and PathFX_histplot.png
# Constructed and saved outputs/output_comparison_network_analysis/visual_graphs/Distribution of edge scores in STRING and PathFX (ZOOMED RIGHT)_histplot.png
# Constructed and saved outputs/output_comparison_network_analysis/visual_graphs/Distribution of edge scores in STRING and PathFX (ZOOMED LEFT)_histplot.png
# Constructed and saved outputs/output_comparison_network_analysis/visual_graphs/Distribution of Number of Interactions per Protein in STRING and PathFX_histplot.png
# Constructed and saved outputs/output_comparison_network_analysis/visual_graphs/Distribution of Number of Interactions per Protein in STRING and PathFX (ZOOMED)_histplot.png
# Constructed and saved outputs/output_comparison_network_analysis/visual_graphs/Distribution of Number of Interactions per Protein in STRING and PathFX (ZOOMED 2x)_histplot.png
# Finished Running comparison_network_analysis.ipynb
#
# Finished Running all iPython Notebooks
#
# Saving Output Folders...
# Folder output_pathfx_network_analysis renamed to outputs/FLTERED_FOR_CLOSE_NODES_output_pathfx_network_analysis successfully
# Folder output_string_network_analysis renamed to outputs/FLTERED_FOR_CLOSE_NODES_output_string_network_analysis successfully
# Folder output_comparison_network_analysis renamed to outputs/FLTERED_FOR_CLOSE_NODES_output_comparison_network_analysis successfully
#
# ================================================================================================
