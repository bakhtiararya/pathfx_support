# %%
import numpy as np
import pandas as pd
import re
import os
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Reading in the several .txt files from STRING as a .csv file to import into pandas

input_file = "inputs/input_string_network_files/9606.protein.links.full.v11.0.txt"
if not os.path.exists(input_file):
    sys.exit("Can't locate input file %s" % input_file)
string_protein_links_df = pd.read_csv(input_file, delim_whitespace=True)


input_file = "inputs/input_string_network_files/9606.protein.info.v11.0.txt"
if not os.path.exists(input_file):
    sys.exit("Can't locate input file %s" % input_file)
string_protein_info_df = pd.read_csv(input_file, sep='\t')

# %%
string_protein_links_df.head(3)
# Out:
#                protein1              protein2  neighborhood  \
# 0  9606.ENSP00000000233  9606.ENSP00000272298             0
# 1  9606.ENSP00000000233  9606.ENSP00000253401             0
# 2  9606.ENSP00000000233  9606.ENSP00000401445             0
#
#    neighborhood_transferred  fusion  cooccurence  homology  coexpression  \
# 0                         0       0          332         0             0
# 1                         0       0            0         0             0
# 2                         0       0            0         0             0
#
#    coexpression_transferred  experiments  experiments_transferred  database  \
# 0                        62            0                      181         0
# 1                         0            0                      186         0
# 2                         0            0                      160         0
#
#    database_transferred  textmining  textmining_transferred  combined_score
# 0                     0           0                     125             490
# 1                     0           0                      56             198
# 2                     0           0                       0             159

# %%
string_protein_info_df.head(3)
# Out:
#     protein_external_id preferred_name  protein_size  \
# 0  9606.ENSP00000000233           ARF5           180
# 1  9606.ENSP00000000412           M6PR           277
# 2  9606.ENSP00000001008          FKBP4           459
#
#                                           annotation
# 0  ADP-ribosylation factor 5; GTP-binding protein...
# 1  Cation-dependent mannose-6-phosphate receptor;...
# 2  Peptidyl-prolyl cis-trans isomerase FKBP4; Imm...

# %%
# list of proteins preferred_name's with 2 protein_external_id's
proteins_with_redundant_ids = ["ENSG00000258947", "ENSG00000239810", "ENSG00000253117", "ENSG00000183628", "ENSG00000205457", 
                               "ENSG00000166160", "ENSG00000216937", "ENSG00000197054", "ENSG00000242852", "ENSG00000243667"]

# Displaying specific proteins with 2 protein_external_id's
string_protein_info_df[string_protein_info_df["preferred_name"].isin(proteins_with_redundant_ids)].sort_values(by='preferred_name', ascending=False)
# Out:
#         protein_external_id   preferred_name  protein_size  \
# 6807   9606.ENSP00000320295  ENSG00000258947           450
# 17817  9606.ENSP00000451560  ENSG00000258947           797
# 1825   9606.ENSP00000254627  ENSG00000253117           477
# 2500   9606.ENSP00000262283  ENSG00000253117           689
# 4579   9606.ENSP00000295121  ENSG00000243667           357
# 18716  9606.ENSP00000477980  ENSG00000243667           765
# 15763  9606.ENSP00000404127  ENSG00000242852           641
# 14173  9606.ENSP00000380840  ENSG00000242852           641
# 9156   9606.ENSP00000347211  ENSG00000239810           436
# 18900  9606.ENSP00000480027  ENSG00000239810           478
# 11948  9606.ENSP00000364165  ENSG00000216937           628
# 10059  9606.ENSP00000355078  ENSG00000216937           486
# 17950  9606.ENSP00000455132  ENSG00000205457           124
# 19498  9606.ENSP00000485467  ENSG00000205457           124
# 12843  9606.ENSP00000369774  ENSG00000197054           397
# 18302  9606.ENSP00000467286  ENSG00000197054           414
# 7740   9606.ENSP00000331681  ENSG00000183628           220
# 19139  9606.ENSP00000482514  ENSG00000183628           220
# 10881  9606.ENSP00000358945  ENSG00000166160           364
# 18392  9606.ENSP00000469970  ENSG00000166160           364
#
#                                               annotation
# 6807   Tubulin beta-3 chain; Tubulin is the major con...
# 17817  Uncharacterized protein; Tubulin is the major ...
# 1825   Otoconin 90; It is unlikely that this protein ...
# 2500   Otoconin-90; It is unlikely that this protein ...
# 4579   Uncharacterized protein DKFZp434B156; Seems to...
# 18716  WD repeat-containing protein 92; Seems to act ...
# 15763  Zinc finger protein 709; May be involved in tr...
# 14173  Zinc finger protein 709; May be involved in tr...
# 9156                              PRAME family member 11
# 18900                             PRAME family member 11
# 11948  Coiled-coil domain containing 7; May play a ro...
# 10059  Coiled-coil domain-containing protein 7; May p...
# 17950  TP53 target 3C; May play a significant role in...
# 19498  TP53 target 3C; May play a significant role in...
# 12843  Zinc finger protein 763; May be involved in tr...
# 18302  Zinc finger protein 763; May be involved in tr...
# 7740   DiGeorge syndrome critical region gene 6; May ...
# 19139  Protein DGCR6; May play a role in neural crest...
# 10881  Opsin 1 (cone pigments), medium-wave-sensitive...
# 18392  Opsin 1 (cone pigments), medium-wave-sensitive...

# %%
# The Code below shows how I found out the discrepancy

# %%
# Count the number of DISTINCT Protein IDs from 9606.protein.info.v11.0.txt and 9606.protein.links.full.v11.0.txt

# "Interaction Table" - 9606.protein.links.full.v11.0.txt
# "Protein Info Table" - 9606.protein.info.v11.0.txt

string_unique_id_interaction_list = []
string_unique_id_interaction_one_list = string_protein_links_df["protein1"].unique()
string_unique_id_interaction_two_list = string_protein_links_df["protein2"].unique()
string_unique_id_interaction_list.extend(string_unique_id_interaction_one_list)
string_unique_id_interaction_list.extend(string_unique_id_interaction_two_list)
string_unique_id_interaction_list = pd.Series(string_unique_id_interaction_list).unique()

print()
print("Number of unique Protein 1 IDs from Interaction table:", len(string_unique_id_interaction_one_list))
print("Number of unique Protein 2 IDs from Interaction table:", len(string_unique_id_interaction_two_list))
print("Number of unique Protein IDs from Interaction table:", len(string_unique_id_interaction_list))
print("Number of unique Protein IDs from Protein Info Table:", len(string_protein_info_df["protein_external_id"]))
print("Number of unique Proteins from Protein Info Table:", len(string_protein_info_df["preferred_name"]))

print()

string_unique_id_interaction_set = set(string_unique_id_interaction_list)
string_unique_id_info_set = set(string_protein_info_df["protein_external_id"])

intersecting_nodes = string_unique_id_interaction_set & string_unique_id_info_set

string_unique_id_interaction_disjoint_set = string_unique_id_interaction_set - intersecting_nodes
string_unique_id_info_disjoint_set = string_unique_id_info_set - intersecting_nodes

print("Number of Protein IDs only in the Interaction table:", len(string_unique_id_interaction_disjoint_set))
print("Number of Protein IDs only in the Info table:",len(string_unique_id_info_disjoint_set))
print()
# Out:
# Number of unique Protein 1 IDs from Interaction table: 19354
# Number of unique Protein 2 IDs from Interaction table: 19354
# Number of unique Protein IDs from Interaction table: 19354
# Number of unique Protein IDs from Protein Info Table: 19566
# Number of unique Proteins from Protein Info Table: 19566
#
# Number of Protein IDs only in the Interaction table: 0
# Number of Protein IDs only in the Info table: 212

# %%
# From this, we know there are 212 listed Proteins NOT in any interaction (isolated vertices in the network graph)
# 212 Protein IDs are listed in 9606.protein.info.v11.0.txt but NOT in 9606.protein.links.full.v11.0.txt

# %%
string_protein_info_df
# Out:
#         protein_external_id   preferred_name  protein_size  \
# 0      9606.ENSP00000000233             ARF5           180
# 1      9606.ENSP00000000412             M6PR           277
# 2      9606.ENSP00000001008            FKBP4           459
# 3      9606.ENSP00000001146          CYP26B1           512
# 4      9606.ENSP00000002125          NDUFAF7           441
# ...                     ...              ...           ...
# 19561  9606.ENSP00000485671  ENSG00000280273           120
# 19562  9606.ENSP00000485672  ENSG00000279458            86
# 19563  9606.ENSP00000485673  ENSG00000279988           243
# 19564  9606.ENSP00000485675  ENSG00000280116            84
# 19565  9606.ENSP00000485678            OR6Q1           317
#
#                                               annotation
# 0      ADP-ribosylation factor 5; GTP-binding protein...
# 1      Cation-dependent mannose-6-phosphate receptor;...
# 2      Peptidyl-prolyl cis-trans isomerase FKBP4; Imm...
# 3      Cytochrome P450 26B1; Involved in the metaboli...
# 4      Protein arginine methyltransferase NDUFAF7, mi...
# ...                                                  ...
# 19561                                        HCG1991042
# 19562                           annotation not available
# 19563                           annotation not available
# 19564                           annotation not available
# 19565  Olfactory receptor 6Q1; Odorant receptor; Olfa...
#
# [19566 rows x 4 columns]

# %%
# There are 19566 records/rows in the 9606.protein.links.full.v11.0.txt file. 

# If there existed a 1-to-1 correspondence between a protein's IDs and a protein's preferred name, then there should be 19566 * 2 = 39132 distinct elements. 
# There is no record of a protein where their ID is the same as their preferred name because all protein IDs for Homo Sapiens start with 9606. 

# 19566 * 2 = 39132

lst = []
lst.extend(list(string_protein_info_df["protein_external_id"]))
lst.extend(list(string_protein_info_df["preferred_name"]))
lst = pd.Series(lst).unique()
print("The number of distinct elements in 'protein_external_id' + 'preferred_name' columns is:", len(lst))
# Out:
# The number of distinct elements in 'protein_external_id' + 'preferred_name' columns is: 39122

# %%
# 39132 - 39122 = 10
# 10 Proteins 

# There should have been a 1-to-1 correspondance in terms of counting the number of "protein_external_id" and "preferred_name"
# If every protein's preferred name had a distinct protein ID then this means there should have been 39132 elements in the list...
# ...not 39122...this means a redundancy exists: more protein IDs than Protein Preferred names

# %%
# Finding Proteins with more than 1 protein ID in 9606.protein.info.v11.0.txt

df = string_protein_info_df[["preferred_name", "protein_size"]]
df = df.groupby(["preferred_name"]).agg(["count"])
df.columns = df.columns.droplevel(0)
duplicate_protein_ids_count = df.reset_index().sort_values(by='count', ascending=False)

# only display the first 20 records of 9606.protein.info.v11.0.txt .... to show count
duplicate_protein_ids_count.head(20)
# Out:
#         preferred_name  count
# 5207   ENSG00000258947      2
# 5115   ENSG00000239810      2
# 5161   ENSG00000253117      2
# 5083   ENSG00000183628      2
# 5097   ENSG00000205457      2
# 5076   ENSG00000166160      2
# 5102   ENSG00000216937      2
# 5090   ENSG00000197054      2
# 5119   ENSG00000242852      2
# 5121   ENSG00000243667      2
# 13058           POLR3H      1
# 13043           POLR2H      1
# 13034           POLR1D      1
# 13035           POLR1E      1
# 13062          POM121C      1
# 13036           POLR2A      1
# 13061           POM121      1
# 13037           POLR2B      1
# 13038           POLR2C      1
# 13039           POLR2D      1

# %%
# We now know only these 10 proteins have 2 protein IDs

"""

ENSG00000258947
ENSG00000239810
ENSG00000253117
ENSG00000183628
ENSG00000205457
ENSG00000166160
ENSG00000216937
ENSG00000197054
ENSG00000242852
ENSG00000243667

"""
print()

# %%
"""

The Protein: ENSG00000258947 has 2 IDs:

- 9606.ENSP00000320295
- 9606.ENSP00000451560

.....yet there exists interaction with similar and distinct proteins....

Protein IDs 2: (See below)
- 9606.ENSP00000485586
- 9606.ENSP00000484841
- 9606.ENSP00000484803
- 9606.ENSP00000484789
- 9606.ENSP00000000233
"""
print()

# %%
string_protein_links_df[string_protein_links_df["protein1"] == "9606.ENSP00000320295"].sort_values(by='protein2', ascending=False)
# Out:
#                      protein1              protein2  neighborhood  \
# 4487786  9606.ENSP00000320295  9606.ENSP00000485663             0
# 4487709  9606.ENSP00000320295  9606.ENSP00000485586             0
# 4486345  9606.ENSP00000320295  9606.ENSP00000484841             0
# 4487086  9606.ENSP00000320295  9606.ENSP00000484803             0
# 4487742  9606.ENSP00000320295  9606.ENSP00000484789             0
# ...                       ...                   ...           ...
# 4487327  9606.ENSP00000320295  9606.ENSP00000062104             0
# 4487519  9606.ENSP00000320295  9606.ENSP00000044462             0
# 4486578  9606.ENSP00000320295  9606.ENSP00000013807             0
# 4486446  9606.ENSP00000320295  9606.ENSP00000001008             0
# 4486238  9606.ENSP00000320295  9606.ENSP00000000233             0
#
#          neighborhood_transferred  fusion  cooccurence  homology  \
# 4487786                         0       0            0         0
# 4487709                         0       0            0         0
# 4486345                         0       0            0         0
# 4487086                         0       0            0         0
# 4487742                         0       0            0         0
# ...                           ...     ...          ...       ...
# 4487327                         0       0            0         0
# 4487519                         0       0            0         0
# 4486578                         0       0            0         0
# 4486446                         0       0            0         0
# 4486238                         0       0            0         0
#
#          coexpression  coexpression_transferred  experiments  \
# 4487786           145                        78            0
# 4487709             0                        61            0
# 4486345             0                        63            0
# 4487086             0                         0            0
# 4487742             0                        63            0
# ...               ...                       ...          ...
# 4487327             0                        63            0
# 4487519           183                         0            0
# 4486578             0                        62            0
# 4486446            87                        62            0
# 4486238             0                        63            0
#
#          experiments_transferred  database  database_transferred  textmining  \
# 4487786                        0         0                     0           0
# 4487709                       85         0                     0         222
# 4486345                      157         0                     0          56
# 4487086                       77         0                     0          89
# 4487742                      109         0                     0          60
# ...                          ...       ...                   ...         ...
# 4487327                        0         0                     0         114
# 4487519                       50         0                     0          53
# 4486578                        0         0                     0         669
# 4486446                        0         0                     0          87
# 4486238                      145         0                     0           0
#
#          textmining_transferred  combined_score
# 4487786                      49             184
# 4487709                       0             273
# 4486345                      98             237
# 4487086                      85             163
# 4487742                      68             170
# ...                         ...             ...
# 4487327                      81             170
# 4487519                       0             200
# 4486578                       0             676
# 4486446                      73             178
# 4486238                      57             178
#
# [1825 rows x 16 columns]

# %%
string_protein_links_df[string_protein_links_df["protein1"] == "9606.ENSP00000451560"].sort_values(by='protein2', ascending=False)
# Out:
#                       protein1              protein2  neighborhood  \
# 10937078  9606.ENSP00000451560  9606.ENSP00000485586             0
# 10936115  9606.ENSP00000451560  9606.ENSP00000485478             0
# 10935518  9606.ENSP00000451560  9606.ENSP00000484841             0
# 10936371  9606.ENSP00000451560  9606.ENSP00000484803             0
# 10937121  9606.ENSP00000451560  9606.ENSP00000484789             0
# ...                        ...                   ...           ...
# 10935711  9606.ENSP00000451560  9606.ENSP00000043402             0
# 10935788  9606.ENSP00000451560  9606.ENSP00000013807             0
# 10935940  9606.ENSP00000451560  9606.ENSP00000005286             0
# 10937239  9606.ENSP00000451560  9606.ENSP00000005257             0
# 10935399  9606.ENSP00000451560  9606.ENSP00000000233             0
#
#           neighborhood_transferred  fusion  cooccurence  homology  \
# 10937078                         0       0            0         0
# 10936115                         0       0            0         0
# 10935518                         0       0            0         0
# 10936371                         0       0            0         0
# 10937121                         0       0            0         0
# ...                            ...     ...          ...       ...
# 10935711                         0       0            0         0
# 10935788                         0       0            0         0
# 10935940                         0       0            0         0
# 10937239                         0       0            0         0
# 10935399                         0       0            0         0
#
#           coexpression  coexpression_transferred  experiments  \
# 10937078             0                        61            0
# 10936115             0                         0            0
# 10935518             0                        63            0
# 10936371             0                         0            0
# 10937121             0                        63            0
# ...                ...                       ...          ...
# 10935711            76                        62            0
# 10935788             0                        62            0
# 10935940           152                         0            0
# 10937239             0                         0            0
# 10935399             0                        63            0
#
#           experiments_transferred  database  database_transferred  textmining  \
# 10937078                       85         0                     0         217
# 10936115                        0         0                     0         221
# 10935518                      157         0                     0          58
# 10936371                       84         0                     0         124
# 10937121                      109         0                     0          56
# ...                           ...       ...                   ...         ...
# 10935711                       50         0                     0           0
# 10935788                        0         0                     0         647
# 10935940                        0         0                     0           0
# 10937239                      167         0                     0           0
# 10935399                      167         0                     0           0
#
#           textmining_transferred  combined_score
# 10937078                       0             268
# 10936115                       0             221
# 10935518                      98             239
# 10936371                      85             201
# 10937121                      68             167
# ...                          ...             ...
# 10935711                     107             166
# 10935788                       0             654
# 10935940                       0             151
# 10937239                      49             173
# 10935399                      57             199
#
# [2072 rows x 16 columns]
